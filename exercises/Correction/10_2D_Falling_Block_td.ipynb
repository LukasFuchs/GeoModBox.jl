# %% [markdown]
# # Stokes-Gleichung (2D)

# %% [markdown]
# ## Zeitabhängiger fallender Block bei konstanter Viskosität
#
# In dieser Übung erweitern wir das zuvor betrachtete instantane Problem des
# fallenden Blocks um die zeitliche Entwicklung der Dichteverteilung.
#
# Dazu koppeln wir die Lösung der Impuls- und Massenerhaltung mit einer
# Advektionsmethode. In jedem Zeitschritt wird zunächst das momentane
# Geschwindigkeits- und Druckfeld für die aktuelle Dichteverteilung berechnet.
# Anschließend wird die Dichteverteilung mit diesem Geschwindigkeitsfeld
# transportiert.
#
# Für die Advektion stehen mehrere Verfahren zur Verfügung:
#
# - Upwind,
# - Staggered Leapfrog,
# - Semi-Lagrange,
# - passive Tracer.
#
# Bei den gitterbasierten Verfahren wird die Dichte direkt advektiert. Bei der
# Tracermethode transportieren die Marker hingegen die Materialphase, aus der
# anschließend die Dichte auf dem numerischen Gitter rekonstruiert wird.
#
# Da die Viskosität räumlich und zeitlich konstant bleibt, ändert sich die
# Koeffizientenmatrix des Stokes-Systems nicht. Sie kann daher einmal vor der
# Zeitschleife assembliert werden. Innerhalb der Zeitschleife
# muss lediglich der von der aktuellen Dichteverteilung abhängige Vektor der
# rechten Seite aktualisiert werden.
#
# ### Das Problem
#
# Anders als im vollständigen Benchmark für dieses Problem, konzentrieren wir uns hier nur auf den **isoviskosen** Fall (im Benchmark betrachtet man die Sinkgeschwindigkeit und Deformation des Blocks in Abhängigkeit des Viskositätskontrastes; [siehe hier](../../examples/StokesEquation/2D/)).
#
# Dabei nehmen wir einen quadratischen Körper mit einer gewissen Breite (**W**), Höhe (**T**), und Dichte ($\rho_b$) an, der sich in einem bestimmten viskosen Medium ($\eta_m$) mit einer gewissen Dichte ($\rho_m$) befindet. Die zu modellierende Umgebung ist ebenfalls quadratisch mit einer gewissen Länge ($L=500\ \textrm{km}$) und Höhe ($H=500\ \textrm{km}$) und wir nehmen überall *free slip* Geschwindigkeitsrandbedingungen an.
#
# <img src="../Figures/Exercise09_1.png" alt="drawing" width="450"/> <br>
# **Abb. 1.** Modellaufbau
#
# Eine detaillierte Beschreibung wie die Modelldomäne durch ein numerisches Gitter aufgeteilt werden kann, sowie die Diskretisierung der **Impulserhaltung** und **Massenerhaltung** in Abhängigkeit von *free slip* oder *no slip* Randbedingungen ist [hier](https://geosci-ffm.github.io/GeoModBox.jl/dev/man/theory/MomentumMain/) gegeben. Auf Grund des Umfanges verzichten wir hier auf eine detaillierte Erklärung.
#
# Wir würden gerne möglichst viele der Advektionsmechanismen in das Problem einbauen, so dass wir neben der Änderung für die Zeitabhängigkeit noch zusätzliche Änderungen vornehmen müssen.
#
# Für zusätzliche Informationen siehe die [vorangehende Übung](./09_2D_Falling_Block.ipynb).
#
# ----------

# %% [markdown]
# Laden wir zuerst einmal die notwendigen Module zur Visualisierung der Ergebnisse, Lösen des linearen Gleichungssystems, Aufstellen der Anfangsbedingungen, und dem Lösen der zweidimensionalen Impulserhaltung. Durch die Verwendung der Advektion und der Tracer kommen noch zusätzliche Module hinzu.

# %%
using Plots
using ExtendableSparse
using GeoModBox.InitialCondition, GeoModBox.MomentumEquation.TwoD
using GeoModBox.AdvectionEquation.TwoD
using GeoModBox.Tracers.TwoD
using Base.Threads
using Printf
start=time()

# %% [markdown]
# Zuerst definieren wir mit Hilfe des Tupels `FD` die Methode der Advektion.

# %%
# Define Numerical Scheme =========================================== #
# Advection ---
#   1) upwind, 2) slf, 3) semilag, 4) tracers
FD          =   (Method     = (Adv=:upwind,),)
# ------------------------------------------------------------------- #

# %% [markdown]
# Mit Hilfe der eingebauten Funktion `IniPhase!()` lässt sich die Anfangsverteilung der Materialphasen für unser Problem *block* erstellen. Je nach Bedarf erstellt die Funktion eine Anfangsverteilung von bestimmten Größen auf dem numerischen Gitter. Für die Verwendung der Funktion benötigen wir das Tupel `Ini`, in dem die Anfangsverteilung der Phase p festgelegt wird. Die mit `IniPhase!()` erzeugte Phasenverteilung auf den Zellzentren wird anschließend verwendet, um den einzelnen Phasen ihre jeweilige Dichte zuzuweisen. Die daraus resultierende Dichteverteilung wird von den gitterbasierten Advektionsmethoden verwendet.

# %%
# Define Initial Condition ========================================== #
# Density --- 
#   1) block
Ini         =   (p=:block,) 
# ------------------------------------------------------------------- #
# Plot Settings ===================================================== #
Pl  =   (
    qinc    =   5,
    qsc     =   100*(60*60*24*365.25)*5e1
)
# ------------------------------------------------------------------- #

# %% [markdown]
# Als nächstes definieren wir die Geometrie unserer Modelldomäne.

# %%
 # Geometry ========================================================== #
 M       =   (
    xmin    =   0.0,
    xmax    =   500.0e3,    # [ m ]
    ymin    =   -500.0e3,   # [ m ]
    ymax    =   0.0,
)
# ------------------------------------------------------------------- #

# %% [markdown]
# Nun definieren wir unsere Gitterauflösung $\left(nc_x = nc_y = 50\right)$ und das numerische Gitter.
#
# Dabei müssen wir sowohl die Gitterbreite $\Delta{x}$ und $\Delta{y}$ als auch die Koordinaten der unterschiedlichen Gitter (*Eckpunkte* und *Zellzentren*) angeben. Dazu definieren wir zuerst die jeweiligen 1-D Koordinatenvektoren, aus denen dann die 2-D Koordinatengitter erstellt werden.

# %%
# Grid ============================================================== #
NC      =   (
    x   =   50, 
    y   =   50,
)
NV      =   (
    x   =   NC.x + 1,
    y   =   NC.y + 1,
)
Δ       =   (
    x   =   (M.xmax - M.xmin)/NC.x,
    y   =   (M.ymax - M.ymin)/NC.y,
)
x       =   (
    c   =   LinRange(M.xmin+Δ.x/2,M.xmax-Δ.x/2,NC.x),
    ce  =   LinRange(M.xmin - Δ.x/2.0, M.xmax + Δ.x/2.0, NC.x+2),
    v   =   LinRange(M.xmin,M.xmax,NV.x),
)
y       =   (
    c   =   LinRange(M.ymin+Δ.y/2,M.ymax-Δ.y/2,NC.y),
    ce  =   LinRange(M.ymin - Δ.y/2.0, M.ymax + Δ.y/2.0, NC.y+2),
    v   =   LinRange(M.ymin,M.ymax,NV.y),
)
x1      =   (
    c2d     =   x.c .+ 0*y.c',
    v2d     =   x.v .+ 0*y.v', 
    vx2d    =   x.v .+ 0*y.ce',
    vy2d    =   x.ce .+ 0*y.v',
)
x   =   merge(x,x1)
y1      =   (
    c2d     =   0*x.c .+ y.c',
    v2d     =   0*x.v .+ y.v',
    vx2d    =   0*x.v .+ y.ce',
    vy2d    =   0*x.ce .+ y.v',
)
y   =   merge(y,y1)
# ------------------------------------------------------------------- #

# %% [markdown]
# Nun müssen wir die physikalischen Parameter definieren, die Gravitationsbeschleunigung $g$, die Viskosität $\eta_0$ ($10^{21}$ Pa·s), die Hintergrunddichte $\rho_0$ (3200 kg/m³), und die Dichte des Blocks $\rho_1$ (3300 kg/m³).
#
# Der Vektor `phase` beinhaltet die Phasennummer, welche in der Funktion `IniPhase!()` und bei der Initialisierung der Marker (`IniTracer2D()`) verwendet wird, um die jeweilge Phase zuzuordnen. Der Vektor $\rho$ beinhaltet die Dichtewerte, die der jeweilige Phase zugeordnet sind.

# %%
# Physics =========================================================== #
g       =   9.81

η₀      =   1.0e21

ρ₀      =   3200.0          #   Background density
ρ₁      =   3300.0          #   Block density

ρ       =   [ρ₀,ρ₁] 
phase   =   [0,1]
# ------------------------------------------------------------------- #

# %% [markdown]
# Für das zeitabhängige Problem legen wir außerdem den Speicherort und den Dateinamen der Animation fest.

# %%
# Animationsettings ================================================= #
path        =   string("./Results/")
anim        =   Plots.Animation(path, String[] )
filename    =   string("10_Falling_",Ini.p,"_iso_td_",FD.Method.Adv)
save_fig    =   1
# ------------------------------------------------------------------- #

# %% [markdown]
# Nun legen wir die Größen der benötigten Felder fest. **Dabei verwenden wir einige neue Felder.**

# %%
# Allocation ======================================================== #
D   =   (
    vx      =   zeros(Float64,NV.x,NC.y+2),
    vy      =   zeros(Float64,NC.x+2,NV.y),
    Pt      =   zeros(Float64,NC...),
    p       =   zeros(Float64,NC...),
    p_ex    =   zeros(Float64,NC.x+2,NC.y+2),
    ρ       =   zeros(Float64,NC...),
    ρ_ex    =   zeros(Float64,NC.x+2,NC.y+2),
    ρ_exo   =   zeros(Float64,NC.x+2,NC.y+2),
    vxc     =   zeros(Float64,NC...),
    vyc     =   zeros(Float64,NC...),
    vxco    =   zeros(Float64,NC...),
    vyco    =   zeros(Float64,NC...),
    vc      =   zeros(Float64,NC...),
    wt      =   zeros(Float64,(NC.x,NC.y)),
    wte     =   zeros(Float64,(NC.x+2,NC.y+2)),
    wtv     =   zeros(Float64,(NV...)),
)
# ------------------------------------------------------------------- #

# %% [markdown]
# Jetzt lassen sich die Randbedingungen und die Anfangsbedingungen festlegen.
#
# Für die Randbedingungen benutzen wir wieder das Tuple `VBC`, in dem die Art des Randes (*free slip* oder *no slip*) an der jeweiligen Position (**E**, **W**, **S**,**N**) definiert ist. Der angegebene Wert `val` bestimmt dann den Wert der Geschwindigkeit an dem jeweiligen Rand.

# %%
# Boundary Conditions =============================================== #
VBC     =   (
    type    =   (E=:freeslip,W=:freeslip,S=:freeslip,N=:freeslip),
    val     =   (E=zeros(NV.y),W=zeros(NV.y),S=zeros(NV.x),N=zeros(NV.x),
                vxE=zeros(NC.y),vxW=zeros(NC.y),vyS=zeros(NC.x),vyN=zeros(NC.x)),
)
# ------------------------------------------------------------------- #

# %% [markdown]
# Als nächstes müssen wir die Parameter für die Zeit und die Zeitschrittlänge definieren.

# %%
# Time ============================================================== #
T   =   ( 
    tmax    =   [0.0],  
    Δfac    =   1.0,         # Faktor für den Courant-Zeitschritt
    Δ       =   [0.0],
    Time    =   [0.0,0.0],
)
T.tmax[1]   =   9.886 * 1e6 * (60*60*24*365.25)   # [ s ]
nt          =   9999
# ------------------------------------------------------------------- #

# %% [markdown]
# Für die tracerbasierte Advektion müssen die passiven Tracer zunächst initialisiert werden.. Die Funktion `IniTracer2D()` initialisiert die Verteilung der Tracer in der gegebenen Modelldomäne (mit, wenn nötig, beliebiger Störung bei der Position) und, falls vorher in `Ini` definiert, wird den Tracern die jeweilige Phase zugewiesen.
#
# Die Tracer werden in der Zeitschleife advektiert und transportieren die Phase. Mithilfe der auf den Tracern gespeicherten Phase wird anschließend eine Materialeigenschaft, hier die Dichte ρ, mit der Funktion `Markers2Cells()` auf das numerische Gitter interpoliert.
#
# Falls eine andere Advektionsmethode gewählt wird, wird die Dichte direkt auf dem Gitter initialisiert. Beachte, die Advektionsroutinen benötigen die Information auf dem erweiterten Gitter. Dabei weist `IniPhase!()` jedem Zellzentrum die entsprechende Materialphase zu. Anschließend wird jeder Phase der zugehörige Dichtewert zugewiesen. Für das Staggered-Leapfrog-Verfahren wird zusätzlich die Dichteverteilung des vorherigen Zeitschritts in `D.ρ_exo` gespeichert.

# %%
# Tracer Advection ================================================== #
if FD.Method.Adv==:tracers 
    # Tracer Initialization ---
    nmx,nmy     =   5,5
    noise       =   0
    nmark       =   nmx*nmy*NC.x*NC.y
    Aparam      =   :phase
    MPC         =   (
            c       =   zeros(Float64,(NC.x,NC.y)),
            v       =   zeros(Float64,(NV.x,NV.y)),
            th      =   zeros(Float64,(nthreads(),NC.x,NC.y)),
            thv     =   zeros(Float64,(nthreads(),NV.x,NV.y)),
    )
    MAVG        = (
            PC_th   =   [similar(D.wte) for _ = 1:nthreads()],  # per thread
            PV_th   =   [similar(D.wtv) for _ = 1:nthreads()],   # per thread
            wte_th  =   [similar(D.wte) for _ = 1:nthreads()],  # per thread
            wtv_th  =   [similar(D.wtv) for _ = 1:nthreads()],  # per thread
    )
    Ma      =   IniTracer2D(Aparam,nmx,nmy,Δ,M,NC,noise,Ini.p,phase)
    # RK4 weights ---
    rkw     =   1.0/6.0*[1.0 2.0 2.0 1.0]   # for averaging
    rkv     =   1.0/2.0*[1.0 1.0 2.0 2.0]   # for time stepping
    # Count marker per cell ---
    CountMPC(Ma,nmark,MPC,M,x,y,Δ,NC,NV)
    # Interpolate from markers to cell ---
    Markers2Cells(Ma,nmark,MAVG.PC_th,D.ρ_ex,MAVG.wte_th,D.wte,x,y,Δ,Aparam,ρ)
    D.ρ     .=  D.ρ_ex[2:end-1,2:end-1]  
else
    # --------------------------------------------------------------- #
    # Initial Condition ============================================= #
    # Phase ---
    # If tracers are used, phases need to be defined on the tracers 
    # directly and are not suppose to be interpolated from the centroids! 
    IniPhase!(Ini.p,D,M,x,y,NC;phase)
    for i in eachindex(phase)
        D.ρ[D.p.==phase[i]] .= ρ[i]
    end
    D.ρ_ex[2:end-1,2:end-1]     .=  D.ρ
    D.ρ_ex[1,:]     .=   D.ρ_ex[2,:]
    D.ρ_ex[end,:]   .=   D.ρ_ex[end-1,:]
    D.ρ_ex[:,1]     .=   D.ρ_ex[:,2]
    D.ρ_ex[:,end]   .=   D.ρ_ex[:,end-1]
    D.ρ_exo         .=   D.ρ_ex
end
# ------------------------------------------------------------------- #

# %% [markdown]
# Nun müssen die Parameter für das lineare Gleichungssystem erstellt werden.
#
# Die Nummerierung der Gleichungen für die *x-Komponente* und die *y-Komponente* der Impulserhaltung, sowie die der *Massenerhaltung*, als auch die Diskretisierung der zu lösenden Gleichungen mit Hilfe der Finiten-Differenzen-Methode ist im Detail [hier](https://geosci-ffm.github.io/GeoModBox.jl/dev/man/theory/MomentumMain/) beschrieben.
#
# Nun wird die globale Nummerierung der Unbekannten für die beiden Geschwindigkeitskomponenten und den Druck erstellt. Sie legt fest, an welcher Position die einzelnen Gittergrößen im globalen Lösungsvektor gespeichert werden.

# %%
# System of Equations =============================================== #
# Numbering, without ghost nodes! ---
off    = [  NV.x*NC.y,                          # vx
            NV.x*NC.y + NC.x*NV.y,              # vy
            NV.x*NC.y + NC.x*NV.y + NC.x*NC.y]  # Pt

Num    =    (
    Vx  =   reshape(1:NV.x*NC.y, NV.x, NC.y), 
    Vy  =   reshape(off[1]+1:off[1]+NC.x*NV.y, NC.x, NV.y), 
    Pt  =   reshape(off[2]+1:off[2]+NC.x*NC.y,NC...),
)
# ------------------------------------------------------------------- #

# %% [markdown]
# Mit der Funktion `Assemblyc()` wird die Koeffizientenmatrix $\mathbf{K}$ des diskretisierten Stokes-Systems assembliert. Die Funktion weist der jeweiligen Gleichung den Wert der benötigten Koeffizienten zu. Da wir ein isoviskoses Problem betrachten, können wir die Koeffizientenmatrix einmal außerhalb der Zeitschleife aufstellen, da sie sich nicht ändert.

# %%
# Assemble Coefficients ============================================= #
K       =   Assemblyc(NC, NV, Δ, η₀, VBC, Num)
# ------------------------------------------------------------------- #

# %% [markdown]
# In jedem Zeitschritt werden
#
# - der von der aktuellen Dichteverteilung abhängige Vektor der rechten Seite aktualisiert,
# - das lineare Gleichungssystem gelöst,
# - die Dichte-, Geschwindigkeits- und Druckfelder visualisiert,
# - die Zeitschrittlänge bestimmt und
# - die Dichte beziehungsweise die Materialphase advektiert.
#
# Die Zeitschrittlänge wird aus einer Courant-basierten Abschätzung bestimmt. Sie begrenzt die während eines Zeitschritts zurückgelegte Strecke relativ zur Gitterweite.

# %%
# Time Loop ========================================================= #
for it = 1:nt
    # Update Time ---
    T.Time[1]   =   T.Time[2] 
    @printf("Time step: #%04d, Time [Myr]: %04e\n ",it,
                T.Time[1]/(60*60*24*365.25)/1.0e6)
    # Momentum Equation ===
    # Update RHS ---
    rhs     =   updaterhsc( NC, NV, Δ, η₀, D.ρ, g, VBC, Num )
    # Solve System of Equations ---
    χ       =   K \ rhs
    # Update Unknown Variables ---
    D.vx[:,2:end-1]     .=  χ[Num.Vx]
    D.vy[2:end-1,:]     .=  χ[Num.Vy]
    D.Pt                .=  χ[Num.Pt]
    # ===
    # Get the velocity on the centroids ---
    for i = 1:NC.x
        for j = 1:NC.y
            D.vxc[i,j]  = (D.vx[i,j+1] + D.vx[i+1,j+1])/2
            D.vyc[i,j]  = (D.vy[i+1,j] + D.vy[i+1,j+1])/2
        end
    end
    @. D.vc        = sqrt(D.vxc^2 + D.vyc^2)
    # ---
    final_step = T.Time[2] >= T.tmax[1]
    # ---
    if mod(it,2) == 0 || final_step || it == 1
        p = heatmap(x.c./1e3,y.c./1e3,D.ρ',color=:inferno,
                xlabel="x[km]",ylabel="y[km]",colorbar=false,
                title="Density",
                aspect_ratio=:equal,xlims=(M.xmin/1e3, M.xmax/1e3), 
                ylims=(M.ymin/1e3, M.ymax/1e3),
                layout=(2,2),subplot=1)
        quiver!(p,x.c2d[1:Pl.qinc:end,1:Pl.qinc:end]./1e3,
                y.c2d[1:Pl.qinc:end,1:Pl.qinc:end]./1e3,
                quiver=(D.vxc[1:Pl.qinc:end,1:Pl.qinc:end].*Pl.qsc,
                        D.vyc[1:Pl.qinc:end,1:Pl.qinc:end].*Pl.qsc), 
                la=0.5,
                color="white",layout=(2,2),subplot=1)
        heatmap!(p,x.c./1e3,y.c./1e3,D.vxc',
                xlabel="x[km]",ylabel="y[km]",colorbar=false,
                title="V_x",color=cgrad(:batlow),
                aspect_ratio=:equal,xlims=(M.xmin/1e3, M.xmax/1e3),
                ylims=(M.ymin/1e3, M.ymax/1e3),
                layout=(2,2),subplot=3)
        heatmap!(p,x.c./1e3,y.c./1e3,D.vyc',
                xlabel="x[km]",ylabel="y[km]",colorbar=false,
                title="V_y",color=cgrad(:batlow),
                aspect_ratio=:equal,xlims=(M.xmin/1e3, M.xmax/1e3),
                ylims=(M.ymin/1e3, M.ymax/1e3),
                layout=(2,2),subplot=4)
        heatmap!(p,x.c./1e3,y.c./1e3,D.Pt',
                xlabel="x[km]",ylabel="y[km]",colorbar=false,
                title="P_t",color=cgrad(:lipari),
                aspect_ratio=:equal,xlims=(M.xmin/1e3, M.xmax/1e3),
                ylims=(M.ymin/1e3, M.ymax/1e3),
                layout=(2,2),subplot=2)
        if save_fig == 1
            Plots.frame(anim)
        elseif save_fig == 0
            display(p)
        end
    end
    if final_step
        break
    end
     # Calculate Time Stepping ---
    T.Δ[1]      =   T.Δfac * minimum((Δ.x,Δ.y)) / 
                        (sqrt(maximum(abs.(D.vx))^2 + maximum(abs.(D.vy))^2))
    @printf("\n")
    # Calculate Time ---
    T.Time[2]   =   T.Time[1] + T.Δ[1]
    if T.Time[2] > T.tmax[1] 
        T.Δ[1]      =   T.tmax[1] - T.Time[1]
        T.Time[2]   =   T.Time[1] + T.Δ[1]
    end
    # Advection ===
    if FD.Method.Adv==:upwind
        upwindc2D!(D.ρ,D.ρ_ex,D.vxc,D.vyc,NC,T.Δ[1],Δ.x,Δ.y)
    elseif FD.Method.Adv==:slf
        slfc2D!(D.ρ,D.ρ_ex,D.ρ_exo,D.vxc,D.vyc,NC,T.Δ[1],Δ.x,Δ.y)
    elseif FD.Method.Adv==:semilag
        if it == 1
            @. D.vxco   =   D.vxc
            @. D.vyco   =   D.vyc
        end
        semilagc2D!(D.ρ,D.ρ_ex,D.vxc,D.vyc,D.vxco,D.vyco,x,y,T.Δ[1])
        @. D.vxco   =   D.vxc
        @. D.vyco   =   D.vyc
    elseif FD.Method.Adv==:tracers
        # Advect tracers ---
        @printf("Running on %d thread(s)\n", nthreads())  
        AdvectTracer2D(Ma,nmark,D,x,y,T.Δ[1],Δ,NC,rkw,rkv)
        CountMPC(Ma,nmark,MPC,M,x,y,Δ,NC,NV)
        # Interpolate phase from tracers to grid ---
        Markers2Cells(Ma,nmark,MAVG.PC_th,D.ρ_ex,MAVG.wte_th,D.wte,x,y,Δ,Aparam,ρ)
        D.ρ     .=   D.ρ_ex[2:end-1,2:end-1]  
    end
end # End Time Loop

# %% [markdown]
# Zuletzt speichern wir noch die Animation.

# %%
# Save Animation ==================================================== #
if save_fig == 1
    # Write the frames to a GIF file
    Plots.gif(anim, string( path, filename, ".gif" ), fps = 15)
    foreach(rm, filter(startswith(string(path,"00")), readdir(path,join=true)))
end
stop=time()
println(stop-start)
