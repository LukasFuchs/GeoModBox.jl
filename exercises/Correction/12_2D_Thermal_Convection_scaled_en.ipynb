# %% [markdown]
# # Thermal Convection – Non-Dimensional Form
#
# One of the major advantages of numerical and analogue models is that they can be formulated in a dimensionless form through appropriate scaling. This non-dimensionalization allows models of different physical scales to be compared directly. By introducing suitable scaling constants, all physical units can be eliminated from the governing equations. Depending on the assumptions made, a small number of dimensionless parameters remain, which provide a concise description of the physical behavior of the system.
#
# ## Problem Statement
#
# We again consider thermal convection, as introduced in the [previous exercise](./11_2D_Thermal_Convection.ipynb).
#
# Under the same assumptions (e.g., the *Boussinesq* approximation, incompressibility, and basal heating), the governing equations for the two-dimensional case are given by:
#
# **Energy equation:**
#
# $\begin{equation}
# \rho_0 c_p \left(\frac{\partial T}{\partial t} + v_j \frac{\partial T}{\partial x_j}\right) = -\frac{\partial q_i}{\partial x_i},
# \end{equation}$
#
# where
#
# - $\rho_0$ is the reference density [kg/m³],
# - $c_p$ is the specific heat capacity [J/kg/K],
# - $T$ is the temperature [K],
# - $t$ is time [s],
# - $v_j$ is the velocity component in the $j$-th spatial direction [m/s], and
# - $q_i$ is the heat flux in the $i$-th direction [W/m²].
#
# **Momentum equation:**
#
# $\begin{equation}
# 0 = -\frac{\partial P_{\mathrm{dyn}}}{\partial x_i} +
# \frac{\partial \tau_{ij}}{\partial x_j} - \rho_0 g_i \alpha T,
# \end{equation}$
#
# where
#
# - $P_{\mathrm{dyn}}$ is the dynamic pressure [Pa],
# - $\tau_{ij}$ is the Cauchy stress tensor [Pa],
# - $g_i$ is the component of the gravitational acceleration vector [m/s²], and
# - $\alpha$ is the coefficient of thermal expansion [1/K].
#
# **Continuity equation:**
#
# $\begin{equation}
# \frac{\partial v_i}{\partial x_i}=0.
# \end{equation}$
#
# ## Scaling
#
# The purpose of non-dimensionalization is to reduce the number of independent physical parameters. Instead of many dimensional material properties, the behavior of the system is described by only a few dimensionless quantities, most notably the **Rayleigh number**.
#
# ### Scaling Constants
#
# There are several possible ways to non-dimensionalize the governing equations. The most important step is the selection of suitable scaling constants. Here we define
#
# $$
# \begin{aligned}
# h_{\mathrm{sc}} &= h, \\
# t_{\mathrm{sc}} &= \frac{h^2}{\kappa}, \\
# v_{\mathrm{sc}} &= \frac{\kappa}{h}, \\
# \tau_{\mathrm{sc}} &= \frac{\eta_0\kappa}{h^2}, \\
# T_{\mathrm{sc}} &= \Delta T, \\
# Q_{\mathrm{sc}} &= \frac{\Delta T\,\kappa\,\rho_0\,c_p}{h^2},
# \end{aligned}
# $$
#
# where
#
# - $h$ is the model height [m],
# - $\kappa = \dfrac{k}{\rho_0 c_p}$ is the thermal diffusivity [m²/s],
# - $\eta_0$ is the reference viscosity [Pa·s], and
# - $\Delta T$ is the temperature difference between the bottom and top boundaries [K].
#
# ### Scaling Relations
#
# Using the scaling constants defined above, the dimensional variables are transformed into dimensionless quantities (primed variables denote dimensionless quantities):
#
# $$
# \begin{aligned}
# h &= h' h_{\mathrm{sc}}, \\
# t &= t' t_{\mathrm{sc}}, \\
# v &= v' v_{\mathrm{sc}}, \\
# \tau &= \tau' \tau_{\mathrm{sc}}, \\
# T &= T' T_{\mathrm{sc}}, \\
# Q &= Q' Q_{\mathrm{sc}}.
# \end{aligned}
# $$
#
# Applying these scaling relations to Equations (1)–(3) eliminates most physical constants. The resulting equations are dimensionless and depend only on a small number of **dimensionless control parameters**.
#
# > **Note:** The following simplification is valid only under the assumptions adopted in this exercise.
#
# ### Rayleigh Number
#
# The most important remaining parameter is the **Rayleigh number**, defined as
#
# $\begin{equation}
# Ra=\frac{\rho_0 g \alpha \Delta T h^3}
# {\eta_0\kappa}.
# \end{equation}$
#
# The Rayleigh number describes the ratio between the forces driving convection (thermal buoyancy) and those resisting convection (viscosity and thermal diffusion). When the Rayleigh number exceeds a critical value, a thermally stratified layer becomes unstable and convection begins.
#
# Regardless of the absolute values of the individual physical parameters, a given Rayleigh number always represents the same convection regime. Consequently, scaled numerical or laboratory models can be used to reproduce large-scale processes such as thermal convection in the Earth's mantle.
#
# The script is designed so that either the Rayleigh number can be specified directly (in which case the reference viscosity $\eta_0$ is adjusted automatically), or the reference parameters can be modified to obtain a desired Rayleigh number.
#
# For a Rayleigh number of $10^4$, we use the following reference values:
#
# $$
# \begin{aligned}
# g &= 9.81~\mathrm{m/s^2},\\
# \rho_0 &= 3300.0~\mathrm{kg/m^3},\\
# k &= 4.125~\mathrm{W/m/K},\\
# c_p &= 1250.0~\mathrm{J/kg/K},\\
# \alpha &= 2.0\times10^{-5}~\mathrm{K^{-1}},\\
# Q_0 &= 0.0~\mathrm{W/m^3},\\
# \eta_0 &= 3.947725485\times10^{23}~\mathrm{Pa\cdot s},\\
# \kappa &= 10^{-6}~\mathrm{m^2/s},\\
# \Delta T &= 2500.0~\mathrm{K}.
# \end{aligned}
# $$
#
# ## Dimensionless Governing Equations
#
# The resulting dimensionless equations are
#
# ### Momentum equation
#
# $x$-component:
#
# $\begin{equation}
# -\frac{\partial P'}{\partial x'} +
# \frac{\partial \tau'_{xj}}{\partial x'_j} = 0,
# \end{equation}$
#
# or, expressed in terms of the velocity components,
#
# $\begin{equation}
# -\frac{\partial P'}{\partial x'} +
# 2\frac{\partial}{\partial x'} \eta'
# \frac{\partial v_x'}{\partial x'} +
# \frac{\partial}{\partial y'} \eta'
# \left(\frac{\partial v_x'}{\partial y'} +
# \frac{\partial v_y'}{\partial x'}\right) = 0.
# \end{equation}$
#
# $y$-component:
#
# $\begin{equation}
# -\frac{\partial P'}{\partial y'} +
# \frac{\partial \tau'_{yj}}{\partial x'_j} = Ra\,T',
# \end{equation}$
#
# or
#
# $\begin{equation}
# -\frac{\partial P'}{\partial y'} +
# 2\frac{\partial}{\partial y'} \eta'
# \frac{\partial v_y'}{\partial y'} +
# \frac{\partial}{\partial x'} \eta'
# \left(\frac{\partial v_y'}{\partial x'} +
# \frac{\partial v_x'}{\partial y'}
# \right) = Ra\,T'.
# \end{equation}$
#
# ### Energy equation
#
# $\begin{equation}
# \left(
# \frac{\partial T'}{\partial t'} + v_j'
# \frac{\partial T'}{\partial x_j'}\right) =
# \frac{\partial^2 T'}{\partial x_i'^2}.
# \end{equation}$
#
# ### Continuity equation
#
# $\begin{equation}
# \frac{\partial v_x'}{\partial x'} +
# \frac{\partial v_y'}{\partial y'} = 0.
# \end{equation}$
#
# Compared to the dimensional formulation, the numerical solution procedure remains unchanged. The primary difference is that the buoyancy term in the momentum equation is replaced by the product of the **Rayleigh number** and the **dimensionless temperature**. Consequently, the Rayleigh number becomes the principal parameter controlling the dynamics of the convection model.

# %% [markdown]
# ## The Solution
#
# ### Exercise
#
# Complete the non-dimensionalization of the governing equations by
#
# - defining the **scaling constants**, and
# - applying the corresponding **scaling relations**.
#
# > **Note:** In addition to applying the scaling relations, the **right-hand side** of the momentum equation must also be scaled (see Equation (8)).
#
# For the **function calls** used to solve the momentum and diffusion equations, we assume that the following **reference parameters** are equal to **1** after non-dimensionalization:
#
# - $\eta_0 = 1$
# - $g = 1$
# - $\kappa = 1$
# - $c_p = 1$
#
# Once the governing equations have been successfully non-dimensionalized, investigate the behavior of the model for **three different Rayleigh numbers**:
#
# $$
# Ra = 10^4,\quad 10^5,\quad \text{and}\quad 10^6.
# $$
#
# **Note:** As the Rayleigh number increases,
#
# - the **flow velocities** increase,
# - convection becomes **more vigorous**, and
# - structures such as *slabs* and *plumes* become **finer and more localized**.
#
# Consequently, the **grid resolution** must be increased to maintain **numerical stability** and **solution accuracy**.
#
# > A higher grid resolution, however, also increases the computational cost significantly.
#
# The grid resolutions provided in this exercise are sufficient for the Rayleigh numbers considered here.
#
# ---
#
# ### Technical Note on the Model Implementation
#
# Unlike the previous exercises, this example makes use of **mutable structures** in `Julia`.
#
# These structures are required because the model parameters must be **modified during the scaling procedure**, which is not possible with the **named tuples** used in the previous exercises, as tuples in Julia are **immutable**, particularly for scalar values.
#
# The mutable structures must be defined separately, for example in a module. Their definitions explicitly specify
#
# - the individual **fields** (e.g., `xmax`, `ymin`), and
# - the corresponding **data types** (scalar, vector, matrix, etc.).
#
# Default values can also be assigned to each field. Consequently, it is usually not necessary to specify every parameter explicitly when creating a new structure, since the default values are often sufficient.
#
# The definitions of these structures can be found here:
#
# 📁 [`Structures.jl`](../../src/Structures.jl) or in the [documentation](https://geosci-ffm.github.io/GeoModBox.jl/dev/man/Ini/).
#
# To use these structures, simply load the `GeoModBox` module. For example,
#
# ```julia
# M = Geometry(
#     xmax = 8700e3,     # [m]
#     ymin = -2900e3     # [m]
# )
# ```
#
# In addition to introducing mutable structures, the numerical solution procedures have been optimized compared to the previous exercise. Since the governing equations are linear and both the viscosity and the thermal properties are assumed to be constant, the assembly and factorization of the coefficient matrices only need to be performed once rather than during every iteration. For the momentum equation, the coefficient matrix can even be assembled before entering the time loop because the viscosity remains constant throughout the simulation.
#
# Furthermore, the amount of information printed to the screen has been reduced (`verbose_step`), which also noticeably improves the overall performance of the time-stepping loop.
#
# ---

# %% [markdown]
# First, we again define the necessary modules:

# %%
using Plots, ExtendableSparse
using GeoModBox
using GeoModBox.InitialCondition, GeoModBox.MomentumEquation.TwoD
using GeoModBox.AdvectionEquation.TwoD, GeoModBox.HeatEquation.TwoD
using GeoModBox.Scaling
using GeoModBox.Tracers.TwoD
using Base.Threads
using Statistics, LinearAlgebra
using Printf, LaTeXStrings, Measures
start=time()

# %% [markdown]
# Next, we specify the methods used to solve the equations and set a few parameters for visualizing the temperature and density fields:

# %%
# Define numerical methods ========================================== #
# Diffusion Scheme --- 
#   1) explicit, 2) implicit, 3) CNA, 4) ADI, 5) dc
# Advection Scheme ---
#   1) upwind, 2) semilag, 3) tracers
#       --- tracers need to be modified ---
# Momentum Equation --- 
#   1) direct, 2) dc 
FD          =   (Method     = (
    Diff=:explicit,
    Adv=:upwind,
    Mom=:direct),
)
# Define Initial Condition ---
# Temperature - 
Ini         =   (T=:lineara,)
# ------------------------------------------------------------------- #
# Plot Einstellungen ================================================ #
Pl  =   (
    qinc        =   5,
    qsc         =   1.0e-4
)
# Animationssettings ================================================ #
# ks          =   scatter()
path        =   string("./Results/")
anim        =   Plots.Animation(path, String[] )
save_fig    =   1
# ------------------------------------------------------------------- #

# %% [markdown]
# In the following, we define the geometry of our model domain.
#
# >**Note:** The size, or more specifically the aspect ratio, indirectly determines the number of grid points if the resolution is kept constant in both spatial directions. The higher the number of grid points, the longer the computation time! An aspect ratio of 2–3 is sufficient. Larger aspect ratios are only efficient to compute for Rayleigh numbers smaller than $10^5$.

# %%
# Modellgeometrie Konstanten ======================================== #
M   =   Geometry(
    xmin    =   0.0,                #   [ m ] 
    xmax    =   8700e3,             #   [ m ]
    ymin    =   -2900e3,            #   [ m ]
    ymax    =   0.0,                #   [ m ]
)
# ------------------------------------------------------------------- #

# %% [markdown]
# Now we can define the reference parameters.
#
# In addition, we can directly specify the *Rayleigh* number here.
# If the given *Rayleigh* number is negative, it will be calculated from the reference parameters.
# If a *Rayleigh* number is provided, then the reference viscosity $\eta_0$ will be adjusted accordingly.

# %%
# Referenzparameter ================================================= #
P   =   Physics(
    g       =   9.81,               #   Schwerebeschleunigung [m/s^2]
    ρ₀      =   3300.0,             #   Hintergunddichte [kg/m^3]
    k       =   4.125,              #   Thermische Leitfaehigkeit [ W/m/K ]
    cp      =   1250.0,             #   Heat capacity [ J/kg/K ]
    α       =   2.0e-5,             #   Thermischer Expnasionskoef. [ K^-1 ]
    Q₀      =   0.0,                #   Waermeproduktionsrate pro Volumen [W/m^3]
    η₀      =   3.947725485e23,     #   Viskositaet [ Pa*s ] [1.778087025e21]
    ΔT      =   2500.0,             #   Temperaturdifferenz
    # Falls Ra < 0 gesetzt ist, dann wird Ra aus den obigen Parametern
    # berechnet. Falls Ra gegeben ist, dann wird die Referenzviskositaet so
    # angepasst, dass die Skalierungsparameter die gegebene Rayleigh-Zahl
    # ergeben.
    Ra      =   1.0e4,              #   Rayleigh number
    Ttop    =   273.15,             #   Temperatur an der Oberfläche [ K ]
)
# ------------------------------------------------------------------- #
# Rayleigh Zahl Bedingungen ========================================= #
if P.Ra < 0
    # Falls die Rayleigh Zahl nicht explizit angegeben wird, dann 
    # wird sie hier berechnet
    P.Ra     =   P.ρ₀*P.g*P.α*P.ΔT*(M.ymax-M.ymin)^3/P.η₀/P.κ
else
    # Falls die Rayleigh Zahl explizit angegeben ist, dann wird hier 
    # die Referenzviskositaet η₀ angepasst. 
    P.η₀     =   P.ρ₀*P.g*P.α*P.ΔT*(M.ymax-M.ymin)^3/P.Ra/P.κ
end
# =================================================================== #

# %% [markdown]
# The scaling constants define the characteristic scales of the problem. All dimensional variables are subsequently divided by their corresponding reference scales, resulting in dimensionless variables. We first define the following scaling constants:

# %%
# Definiere Skalierungskonstanten =================================== # 
S   =   ScalingConstants!(M,P)
# ------------------------------------------------------------------- #

# %% [markdown]
# ... and the numerical grid. For this, we use the same grid resolution $\Delta{x}$ and $\Delta{y}$ in the horizontal and vertical directions, with 58 km.

# %%
# Gittereinstellungen =============================================== #
NC  =   (
    x   =   150,
    y   =   50,
)
NV      =   (
    x   =   NC.x + 1,
    y   =   NC.y + 1,
)
Δ       =   GridSpacing(
    x   =   (M.xmax - M.xmin)/NC.x,
    y   =   (M.ymax - M.ymin)/NC.y,
)
# ------------------------------------------------------------------- #

# %% [markdown]
# Next, we initialize the fields for our variables. Since we want to keep different *solvers* available as options, we need to allocate many fields here.

# %%
# Initialisierung der Datenfelder =================================== #
D       =   DataFields(
    Q       =   zeros(Float64,(NC...)),
    T       =   zeros(Float64,(NC...)),
    T0      =   zeros(Float64,(NC...)),
    T_ex    =   zeros(Float64,(NC.x+2,NC.y+2)),
    T_ex0   =   zeros(Float64,(NC.x+2,NC.y+2)),
    Told_ex =   zeros(Float64,(NC.x+2,NC.y+2)),
    ρ       =   ones(Float64,(NC...)),
    vx      =   zeros(Float64,(NV.x,NV.y+1)),
    vy      =   zeros(Float64,(NV.x+1,NV.y)),    
    Pt      =   zeros(Float64,(NC...)),
    vxc     =   zeros(Float64,(NC...)),
    vyc     =   zeros(Float64,(NC...)),
    vxco    =   zeros(Float64,(NC...)),
    vyco    =   zeros(Float64,(NC...)),
    vc      =   zeros(Float64,(NC...)),
    wt      =   zeros(Float64,(NC...)),
    wte     =   zeros(Float64,(NC.x+2,NC.y+2)),
    wtv     =   zeros(Float64,(NV...)),
    ΔTtop   =   zeros(Float64,NC.x),
    ΔTbot   =   zeros(Float64,NC.x),
    Tmax    =   0.0,
    Tmin    =   0.0,
    Tmean   =   0.0,
)
# Wärmeproduktionsrate ------
@. D.Q      =   P.Q₀
# ------------------------------------------------------------------- #
# Needed for the defect correction solution ---
divV        =   zeros(Float64,NC...)
ε           =   (
    xx      =   zeros(Float64,NC...), 
    yy      =   zeros(Float64,NC...), 
    xy      =   zeros(Float64,NV...),
)
τ           =   (
    xx      =   zeros(Float64,NC...), 
    yy      =   zeros(Float64,NC...), 
    xy      =   zeros(Float64,NV...),
)
# Residuals ---
Fm     =    (
    x       =   zeros(Float64,NV.x, NC.y), 
    y       =   zeros(Float64,NC.x, NV.y)
)
FPt         =   zeros(Float64,NC...)
# ------------------------------------------------------------------- #
# Heat Flux calculations ---
Tv1         =   zeros(NV.x,1)
Tv2         =   zeros(NV.x,1)
dTdy        =   zeros(NV.x,1)
# ------------------------------------------------------------------- #

# %% [markdown]
# Now we can determine the temporal parameters. In particular, we need to specify the **maximum time step length** and the **maximum model time**.
#
# For the maximum time step, we must ensure that the **stability criteria** are satisfied (this applies mainly when using certain finite difference schemes).
# The stability criteria can also be adjusted using the multiplication factors $\Delta facc$ and $\Delta facd$.
#
# This means that we must compute the time step length according to:
#
# - the **diffusion stability criterion**, and
# - the **Courant criterion**.
#
# The maximum time step is then given by the **minimum** of the two.
#
# For the maximum time and the maximum number of iterations, we initially choose values *ad hoc*.
# In practice, the simulation should stop once the **average velocity no longer changes statistically**, indicating that the system has reached a steady state.

# %%
# Zeitparameter ===================================================== #
T   =   TimeParameter(
    tmax    =   1000000.0,          #   [ Ma ]
    Δfacc   =   0.9,                #   Courant time factor
    Δfacd   =   0.9,                #   Diffusion time factor
    itmax   =   10000,              #   Maximum iterations
)
T.tmax      =   T.tmax*1e6*T.year    #   [ s ]
T.Δc        =   T.Δfacc * minimum((Δ.x,Δ.y)) / 
                    (sqrt(maximum(abs.(D.vx))^2 + maximum(abs.(D.vy))^2))
T.Δd        =   T.Δfacd * (1.0 / (2.0 * P.κ *(1.0/Δ.x^2 + 1/Δ.y^2)))

T.Δ         =   minimum([T.Δd,T.Δc])
# Statistics -------------------------------------------------------- #
Time            =   zeros(T.itmax)
Nu              =   zeros(T.itmax)
meanV           =   zeros(T.itmax)
meanT           =   zeros(T.itmax)
epsV_history    =   fill(NaN, T.itmax)
find            =   0
count           =   0
epsV0           =   0
final_step      =   0 
# ------------------------------------------------------------------- #

# %% [markdown]
# We have now defined all parameters and constants required for scaling, and can apply the **scaling laws**:

# %%
# Skalierungsgesetze ================================================ #
ScaleParameters!(S,M,Δ,T,P,D)
# ------------------------------------------------------------------- #

# %% [markdown]
# After applying the scaling laws, all variables and material parameters become dimensionless. As a result, the reference scales are normalized to unity and no longer appear explicitly in the governing equations.
#
# Using the dimensionless quantities, we can now define the dimensionless coordinates of our model:

# %%
# Koordinaten ======================================================= #
x       =   (
    c   =   LinRange(M.xmin+Δ.x/2,M.xmax-Δ.x/2,NC.x),
    ce  =   LinRange(M.xmin - Δ.x/2.0, M.xmax + Δ.x/2.0, NC.x+2),
    v   =   LinRange(M.xmin,M.xmax,NV.x),
)
y       =   (
    c   =   LinRange(M.ymin+Δ.y/2,M.ymax-Δ.y/2,NC.y),
    ce  =   LinRange(M.ymin - Δ.y/2.0, M.ymax + Δ.y/2.0, NC.y+2),
    v   =   LinRange(M.ymin,M.ymax,NV.y),
)
x1      =   (
    c2d     =   x.c .+ 0*y.c',
    v2d     =   x.v .+ 0*y.v', 
    vx2d    =   x.v .+ 0*y.ce',
    vy2d    =   x.ce .+ 0*y.v',
)
x   =   merge(x,x1)
y1      =   (
    c2d     =   0*x.c .+ y.c',
    v2d     =   0*x.v .+ y.v',
    vx2d    =   0*x.v .+ y.ce',
    vy2d    =   0*x.ce .+ y.v',
)
y   =   merge(y,y1)
# ------------------------------------------------------------------- #

# %% [markdown]
# As an initial condition, we prescribe a temperature profile that increases linearly with depth and contains a small elliptical thermal anomaly (`:lineara`). The vertical temperature gradient is determined by the temperature difference $\Delta T$ and the model height $H$.
#
# When markers are **not** used to advect the temperature field, the initial condition is calculated using the `IniTemperature!()` routine.
#
# > **Note:** Although marker-based temperature advection is available in this exercise, its use is currently not recommended for such long-running models. The corresponding routines would benefit from further optimization, for example through subgrid diffusion and the removal and reseeding of markers. The resulting temperature field already agrees reasonably well with the expected solution, but it is still affected by considerable numerical noise. Marker-based temperature advection is nevertheless included here in preparation for future versions of `GeoModBox.jl`.

# %%
# Anfangsbedingungen ================================================ #
# Temperatur ------
IniTemperature!(Ini.T,M,NC,D,x,y;Tb=P.Tbot,Ta=P.Ttop)
if FD.Method.Adv==:tracers 
    # Tracer Initialization ---
    nmx,nmy     =   3,3
    noise       =   0
    nmark       =   nmx*nmy*NC.x*NC.y
    Aparam      =   :thermal
    MPC         =   (
        c       =   zeros(Float64,(NC.x,NC.y)),
        v       =   zeros(Float64,(NV.x,NV.y)),
        th      =   zeros(Float64,(nthreads(),NC.x,NC.y)),
        thv     =   zeros(Float64,(nthreads(),NV.x,NV.y)),
    )
    MAVG        = (
        PC_th   =   [similar(D.wte) for _ = 1:nthreads()],  # per thread
        PV_th   =   [similar(D.wtv) for _ = 1:nthreads()],   # per thread
        wte_th  =   [similar(D.wte) for _ = 1:nthreads()],  # per thread
        wtv_th  =   [similar(D.wtv) for _ = 1:nthreads()],  # per thread
    )
    Ma      =   IniTracer2D(Aparam,nmx,nmy,Δ,M,NC,noise,:nothing,:nothing)
    # RK4 weights ---
    rkw     =   1.0/6.0*[1.0 2.0 2.0 1.0]   # for averaging
    rkv     =   1.0/2.0*[1.0 1.0 2.0 2.0]   # for time stepping
    # Count marker per cell ---
    CountMPC(Ma,nmark,MPC,M,x,y,Δ,NC,NV)
    # Interpolate from markers to cell ---
    @threads for k = 1:nmark
        Ma.T[k] =   FromCtoM(D.T_ex, k, Ma, x, y, Δ, NC)
    end
    ΔT_grid     =   zeros(Float64,(NC.x+2,NC.y+2))
end
# ------------------------------------------------------------------- #

# %% [markdown]
# For the boundary conditions, we must specify constraints for both the temperature and the momentum equations. For the thermal boundary conditions, we assume:
#
# 1. North  – Dirichlet
# 2. South  – Dirichlet
# 3. West   – Neumann
# 4. East   – Neumann
#
# For the velocity boundary conditions, we assume **free-slip** on all sides.

# %%
# Boundary Conditions =============================================== #
# Temperature ------
TBC     = (
    type    = (W=:Neumann, E=:Neumann,N=:Dirichlet,S=:Dirichlet),
    val     = (W=zeros(NC.y),E=zeros(NC.y),
                    N=P.Ttop.*ones(NC.x),S=P.Tbot.*ones(NC.x)))
# Velocity ------
VBC     =   (
    type    =   (E=:freeslip,W=:freeslip,S=:freeslip,N=:freeslip),
    val     =   (E=zeros(NV.y),W=zeros(NV.y),S=zeros(NV.x),N=zeros(NV.x),
                vxE=zeros(NC.y),vxW=zeros(NC.y),vyS=zeros(NC.x),vyN=zeros(NC.x)),
)
# ------------------------------------------------------------------- #
filename    =   string("12_ThermalConvection_",P.Ra,
                            "_",NC.x,"_",NC.y,
                            "_",Ini.T,"_",FD.Method.Adv,"_",FD.Method.Diff,
                            "_",FD.Method.Mom)

# %% [markdown]
# In the following, the parameters required to solve the linear systems of equations are defined. These depend on the selected finite-difference discretization schemes.

# %%
# Lineares Gleichungssystem ========================================= #
# Impulserhaltung (IEG) ------
off     = [ NV.x*NC.y,                          # vx
            NV.x*NC.y + NC.x*NV.y,              # vy
            NV.x*NC.y + NC.x*NV.y + NC.x*NC.y ] # Pt

Num    =    (
    Vx  =   reshape(1:NV.x*NC.y, NV.x, NC.y), 
    Vy  =   reshape(off[1]+1:off[1]+NC.x*NV.y, NC.x, NV.y), 
    Pt  =   reshape(off[2]+1:off[2]+NC.x*NC.y,NC...),
    T   =   reshape(1:NC.x*NC.y, NC.x, NC.y),
)
χ       =   zeros(maximum(Num.Pt))      #   Unknown Vector ME
rhsM    =   zeros(maximum(Num.Pt))      #   Right-hand Side ME
if FD.Method.Mom==:dc
    ndofM       =   maximum(Num.Pt) 
    niterM      =   50
    atolM       =   1e-10       #   Absolute tolerance
    rtolM       =   1e-8        #   Relative tolerance; r = atolM0/atolM
    RM          =   0.0         #   Initialize absolute residual    
    RMrel       =   0.0         #   Initialize relative residual 
    KM          =   ExtendableSparseMatrix(ndofM,ndofM)
end
KM              =   Assemblyc(NC, NV, Δ, 1.0, VBC, Num)
KMfac           =   lu(KM.cscmatrix)
# === Temperature Equation ======
ndofT           =   maximum(Num.T)
if FD.Method.Diff==:implicit || FD.Method.Diff==:CNA
    if FD.Method.Diff==:CNA
        K1      =   ExtendableSparseMatrix(ndofT,ndofT)
        K2      =   ExtendableSparseMatrix(ndofT,ndofT)
    else
        K       =   ExtendableSparseMatrix(ndofT,ndofT)
    end
    rhs         =   zeros(ndofT)
elseif FD.Method.Diff==:dc
    niterT      =   10
    ϵT          =   1e-10
    K           =   ExtendableSparseMatrix(ndofT,ndofT)
    R           =   zeros(Float64,NC...)
    δT          =   zeros(ndofT)
    ∂2T         =   (∂x2=zeros(NC.x, NC.y), ∂y2=zeros(NC.x, NC.y),
                    ∂x20=zeros(NC.x, NC.y), ∂y20=zeros(NC.x, NC.y))
end
# ------------------------------------------------------------------- #

# %% [markdown]
# Now we can solve the equations inside a time loop. The following steps must be carried out:
#
# 1. Initialize the unknown vector and right-hand side for the momentum equation
# 2. Compute the current time
# 3. Zero the velocity and pressure fields
# 4. Solve the momentum equations
# 5. Update the velocity and pressure fields
# 6. Compute velocities at the *centroids*
# 7. Adjust the maximum time step
# 8. Visualize velocity, temperature, and density
# 9. Solve the advection equation
# 10. Solve the diffusion equation
# 11. Compute diagnostic measures (e.g., **Nusselt** number, $V_{RMS}$, etc.)

# %%
# Zeitschleife ====================================================== #
for it = 1:T.itmax
    R0      =   0
    verbose_step    =   mod(it, 250) == 0 || it == 1 || final_step == 1
    if it>1
        Time[it]  =   Time[it-1] + T.Δ
    end
    verbose_step && @printf("Time step: #%04d, Time [non-dim]: %04e\n ",it,
                    Time[it])
    # IEG ------
    verbose_step && @printf("---Momentum Calculation ---\n")
    if it == 1
        D.vx    .=  0.0
        D.vy    .=  0.0 
        D.Pt    .=  0.0
    end
    if FD.Method.Mom==:direct
        # Update RHS ---
        # rechte Seite definiert durch die Boussinesq Annäherung
        rhsM    =   updaterhsc( NC, NV, Δ, 1.0, -P.Ra*D.T, 1.0, VBC, Num )
        # Lösen des linearen Gleichungssystems ---
        χ       =   KMfac \ rhsM
        # Update unbekannte Variablen ---
        D.vx[:,2:end-1]     .=  χ[Num.Vx]
        D.vy[2:end-1,:]     .=  χ[Num.Vy]
        D.Pt                .=  χ[Num.Pt]
    elseif FD.Method.Mom==:dc
        @. D.ρ  =   -P.Ra*D.T
        # Anfangsresiduum ------
        for iter = 1:niterM
            Residuals2Dc!(D,VBC,ε,τ,divV,Δ,1.0,1.0,Fm,FPt)
            rhsM[Num.Vx]    .=   Fm.x
            rhsM[Num.Vy]    .=   Fm.y
            rhsM[Num.Pt]    .=   FPt
            RM          =   norm(rhsM)/sqrt(length(rhsM))
            if iter == 1
                R0 = max(RM, eps())
            end
            RMrel       =   RM/R0
            if verbose_step
                @printf("   MCE %2d: ||R|| = %1.4e, ||R||/||R₀|| = %1.4e\n",iter,RM,RMrel)
            end
            (RM < atolM || RM/R0 < rtolM) && break
            # Lösen des lineare Gleichungssystems ------
            χ      .=   - ( KMfac \ rhsM )
            # Update unbekante Variablen ------
            D.vx[:,2:end-1]     .+=  χ[Num.Vx]
            D.vy[2:end-1,:]     .+=  χ[Num.Vy]
            D.Pt                .+=  χ[Num.Pt]
        end
    end
    # ======
    # Berechnung der Geschwindikeit auf den Centroids ------
    for i = 1:NC.x
        for j = 1:NC.y
            D.vxc[i,j]  = (D.vx[i,j+1] + D.vx[i+1,j+1])/2
            D.vyc[i,j]  = (D.vy[i+1,j] + D.vy[i+1,j+1])/2
        end
    end
    @. D.vc        = sqrt(D.vxc^2 + D.vyc^2)
    # ---
    # Heat flow at the surface ====================================== #
    # Get temperature at the vertices 
    @. Tv1  =   (D.T_ex[1:end-1,end] + D.T_ex[2:end,end] + 
                    D.T_ex[1:end-1,end-1] + D.T_ex[2:end,end-1])/4
    @. Tv2  =   (D.T_ex[1:end-1,end-1] + D.T_ex[2:end,end-1] + 
                    D.T_ex[1:end-1,end-2] + D.T_ex[2:end,end-2])/4
    # Calculate temperature gradient --- 
    @. dTdy =   -(Tv1 - Tv2)/Δ.y
    # Calculate Nusselt number ---
    Nu[it]     =   0.0
    # Trapezoidal integration -
    for i = 1:NV.x
        if i == 1 || i == NV.x
            afac = 1
        else
            afac = 2
        end
        Nu[it]     += afac * dTdy[i]
    end
    Nu[it]     *=   Δ.x/2
    Nu[it]     /= (M.xmax - M.xmin)
    # Mean Temperature ---
    meanT[it]   =   mean(D.T)
    # Root Mean Square Velocity ---
    meanV[it] = sqrt(mean(D.vxc.^2 .+ D.vyc.^2))
    # --------------------------------------------------------------- #
    # Berechnung der Zeitschrittlänge =============================== #
    T.Δc        =   T.Δfacc * minimum((Δ.x,Δ.y)) / 
            (sqrt(maximum(abs.(D.vx))^2 + maximum(abs.(D.vy))^2))
    T.Δd        =   T.Δfacd * (1.0 / (2.0 *(1.0/Δ.x^2 + 1/Δ.y^2)))
    T.Δ         =   minimum([T.Δd,T.Δc])
    if Time[it] + T.Δ >= T.tmax
        T.Δ         =   T.tmax - Time[it]
        final_step  =   1
    end
    # Plot ========================================================== #
    if verbose_step
        p = plot(layout=(2,1),size=(1200,800),dpi = 300,
            guidefontsize = 22, tickfontsize = 22,
            titlefontsize = 22)
        heatmap!(p,x.c,y.c,D.T',
                xlabel="",ylabel=L"y",colorbar=true,
                framestyle =:box,
                xformatter = _ -> "",
                left_margin = 10mm,
                right_margin = 10mm, 
                title=L"Temperature",color=cgrad(:lajolla),
                aspect_ratio=:equal,xlims=(M.xmin, M.xmax),
                ylims=(M.ymin, M.ymax),clims=(0,1),
                subplot=1)
        heatmap!(p,x.c,y.c,D.vc',color=:imola,
            xlabel=L"x",ylabel=L"y",colorbar=true,
            framestyle =:box,
            title=L"Velocity",aspect_ratio=:equal,
            xlims=(M.xmin, M.xmax), 
            ylims=(M.ymin, M.ymax),
            subplot=2)
        contour!(p,x.c,y.c,D.T',lw=1,
            color="white",cbar=true,alpha=0.5,
            subplot=1)     
        quiver!(p,x.c2d[1:Pl.qinc:end,1:Pl.qinc:end],
            y.c2d[1:Pl.qinc:end,1:Pl.qinc:end],
            quiver=(D.vxc[1:Pl.qinc:end,1:Pl.qinc:end].*Pl.qsc,
                    D.vyc[1:Pl.qinc:end,1:Pl.qinc:end].*Pl.qsc),
            la=0.5,color="black",
            subplot=2)
        if save_fig == 1
            Plots.frame(anim)
        elseif save_fig == 0
            display(p)
        end
    end
    # --------------------------------------------------------------- #
    # Advektion ===================================================== #
    if FD.Method.Adv==:upwind
        upwindc2D!(D.T,D.T_ex,D.vxc,D.vyc,NC,T.Δ,Δ.x,Δ.y)
    elseif FD.Method.Adv==:semilag
        if it == 1
            D.vxco  =   copy(D.vxc)
            D.vyco  =   copy(D.vyc)
        end
        semilagc2D!(D.T,D.T_ex,D.vxc,D.vyc,D.vxco,D.vyco,x,y,T.Δ)
        D.vxco  =   copy(D.vxc)
        D.vyco  =   copy(D.vyc)
    elseif FD.Method.Adv==:tracers
        # Advect tracers ---
        verbose_step && @printf("Running on %d thread(s)\n", nthreads())  
        @. ΔT_grid     =   D.T_ex - D.Told_ex
        @threads for k = 1:nmark
            local ΔTm       =   FromCtoM(ΔT_grid, k, Ma, x, y, Δ, NC)
            Ma.T[k]     += ΔTm
        end
        AdvectTracer2D(Ma,nmark,D,x,y,T.Δ,Δ,NC,rkw,rkv)
        CountMPC(Ma,nmark,MPC,M,x,y,Δ,NC,NV)
        # Interpolate phase from tracers to grid ---
        Markers2Cells(Ma,nmark,MAVG.PC_th,D.T_ex,MAVG.wte_th,D.wte,x,y,Δ,Aparam,0)           
        D.T         .=  D.T_ex[2:end-1,2:end-1]
        D.Told_ex   .=  D.T_ex
    end
    # --------------------------------------------------------------- #
    # Diffusion ===================================================== #
    verbose_step && @printf("---Energy Calculation---\n")
    if FD.Method.Diff==:explicit
        ForwardEuler2Dc!(D, 1.0, Δ.x, Δ.y, T.Δ, NC, TBC)
    elseif FD.Method.Diff==:implicit
        BackwardEuler2Dc!(D, 1.0, Δ.x, Δ.y, T.Δ, NC, TBC, rhs, K, Num)
    elseif FD.Method.Diff==:CNA
        CNA2Dc!(D, 1.0, Δ.x, Δ.y, T.Δ, NC, TBC, rhs, K1, K2, Num)
    elseif FD.Method.Diff==:ADI
        ADI2Dc!(D, 1.0, Δ.x, Δ.y, T.Δ, NC, TBC)
    elseif FD.Method.Diff==:dc
        D.T0    .=  D.T
        # Assemble linear system
        K  = AssembleMatrix2Dc(1.0, TBC, Num, NC, Δ, T.Δ;C=0.5)
        # Solve for temperature correction: Cholesky factorisation
        Kc = cholesky(K.cscmatrix)
        for iter = 1:niterT
            # Evaluate residual
            ComputeResiduals2Dc!( R, D.T, D.T_ex, D.T0, D.T_ex0, ∂2T, 
                1.0, TBC, Δ, T.Δ; C = 0.5 )
            verbose_step && @printf("||R_T|| = %1.4e\n", norm(R)/sqrt(length(R)))
            norm(R)/sqrt(length(R)) < ϵT ? break : nothing
            # Solve for temperature correction: Back substitutions
            δT .= -(Kc\R[:])
            # Update temperature
            @. D.T += δT[Num.T]
        end        
        # Update extended field for advection scheme --- 
        D.T_ex[2:end-1,2:end-1]     .=  D.T
    end
    # --------------------------------------------------------------- #
    # Check break =================================================== #
    # If the maximum time is reached or if the models reaches steady 
    # state the time loop is stoped! 
    if Time[it] > 0.0038
    epsC    =   0.0001
        ind = searchsortedfirst(@view(Time[1:it]), Time[it] - 0.0038)
        epsV    =   std(@view meanV[ind:it])
        if count == 0
            epsV0   = max(epsV, eps(Float64))
            count   += 1
        end
        epsV        /= epsV0
        epsV_history[it] = epsV
        find    =   it
        verbose_step && @printf("ε_Vr = %g, ε_Cr = %g \n",epsV,epsC)
        if Time[it] >= T.tmax
            @printf("Maximum time reached!\n")
            find    =   it
            break
        elseif (epsV <= epsC)
            @printf("Convection reaches steady state at %i!\n",it)
            find    =   it
            break
        end
    end
    # --------------------------------------------------------------- #
    verbose_step && @printf("\n")
end

# %%
@show find

# %% [markdown]
# Finally, we compute the statistical diagnostic parameters:

# %%
if save_fig == 1
        # Write the frames to a GIF file
        Plots.gif(anim, string( path, filename, ".gif" ), fps = 15)
        foreach(rm, filter(startswith(string(path,"00")), readdir(path,join=true)))
end
valid   =   findall(isfinite, epsV_history)
ks  = plot(
        valid,
        log10.(epsV_history[valid]),
        xlabel = "it",
        ylabel = "log₁₀(εᵥ/εᵥ₀)",
        label = "",
        markershape = :circle,
        markercolor = :black,
)
# Save final figure ===================================================== #
p2 = plot(layout=(2,1),size=(1200,800),dpi = 300,
        guidefontsize = 22, tickfontsize = 22,
        titlefontsize = 22)
heatmap!(p2,x.c,y.c,D.T',
        xlabel="",ylabel=L"y",colorbar=true,
        framestyle =:box,
        xformatter = _ -> "",
        left_margin = 10mm,
        right_margin = 10mm, 
        title=L"Temperature",color=cgrad(:lajolla),
        aspect_ratio=:equal,xlims=(M.xmin, M.xmax),
        ylims=(M.ymin, M.ymax),clims=(0,1),
        subplot=1)
heatmap!(p2,x.c,y.c,D.vc',color=:imola,
        xlabel=L"x",ylabel=L"y",colorbar=true,
        framestyle =:box,
        title=L"Velocity",aspect_ratio=:equal,
        xlims=(M.xmin, M.xmax), 
        ylims=(M.ymin, M.ymax),
        subplot=2)
        contour!(p2,x.c,y.c,D.T',lw=1,
        color="white",cbar=true,alpha=0.5,
        subplot=1)     
quiver!(p2,x.c2d[1:Pl.qinc:end,1:Pl.qinc:end],
        y.c2d[1:Pl.qinc:end,1:Pl.qinc:end],
        quiver=(D.vxc[1:Pl.qinc:end,1:Pl.qinc:end].*Pl.qsc,
                D.vyc[1:Pl.qinc:end,1:Pl.qinc:end].*Pl.qsc),
        la=0.5,color="black",
        subplot=2)
if save_fig == 1
savefig(ks,string("./Results/12_ThermalConvection_Scaled_iterations_",P.Ra,
        "_",NC.x,"_",NC.y,
        "_",Ini.T,"_",FD.Method.Adv,"_",FD.Method.Diff,"_",FD.Method.Mom,".png"))
savefig(p2,string("./Results/12_ThermalConvection_Scaled_Final_Stage_",P.Ra,
        "_",NC.x,"_",NC.y,"_it_",find,"_",
        Ini.T,"_",FD.Method.Adv,"_",FD.Method.Diff,"_",FD.Method.Mom,".png"))
elseif save_fig == 0
        display(p2)
        display(ks)
end
# ----------------------------------------------------------------------- #
# Plot time serieses ==================================================== #
q2  =   plot(layout=(2,1),size=(1200,800),dpi = 300,
                guidefontsize = 22, tickfontsize = 22,
                titlefontsize = 22,
                left_margin = 10mm, right_margin = 10mm, 
                bottom_margin = 10mm, top_margin = 10mm)
plot!(q2,Time[1:find],Nu[1:find],
        xlabel="", ylabel=L"Nu",label="",
        xformatter = _ -> "",
        framestyle =:box,linewidth=2,
        xlims=(0.0,Time[find]),
        subplot=1)
plot!(q2,Time[1:find],meanV[1:find],
        xlabel=L"Time [ non-dim ]", ylabel=L"V_{RMS}",
        label="",
        framestyle =:box,linewidth=2,
        xlims=(0.0,Time[find]),
        subplot=2)
if save_fig == 1
savefig(q2,string("./Results/12_ThermalConvectionTimeSeries_Scaled_",P.Ra,
                        "_",NC.x,"_",NC.y,"_",Ini.T,"_",FD.Method.Adv,"_",FD.Method.Diff,"_",FD.Method.Mom,".png"))
elseif save_fig == 0
display(q2)
end
# ======================================================================= #
stop=time()
println(stop-start)

# %%
@show stop-start
