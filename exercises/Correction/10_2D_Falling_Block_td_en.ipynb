# %% [markdown]
# # Stokes Equation (2D)

# %% [markdown]
# ## Time-Dependent Falling Block with Constant Viscosity
#
# In this exercise, we extend the previously considered instantaneous falling-block problem by introducing the temporal evolution of the material distribution.
#
# To achieve this, we couple the solution of the momentum and mass conservation equations with an advection method. At each timestep, the instantaneous velocity and pressure fields are first computed for the current density distribution. The material is then transported using the resulting velocity field.
#
# Several advection methods are available:
#
# - Upwind,
# - Staggered Leapfrog,
# - Semi-Lagrangian,
# - passive tracers.
#
# For the grid-based methods, the density is advected directly. In contrast, the tracer method transports the material phase using passive markers. The density field is then reconstructed on the numerical grid from the tracer distribution.
#
# Because the viscosity remains spatially and temporally constant, the coefficient matrix of the Stokes system does not change. It can therefore be assembled once before entering the time loop. During the simulation, only the right-hand-side vector, which depends on the current density distribution, needs to be updated.
#
# ### The Problem
#
# Unlike the complete benchmark for this problem, we consider only the **isoviscous** case. In the full benchmark, the sinking velocity and deformation of the block are investigated as a function of the viscosity contrast; [see here](../../examples/StokesEquation/2D/).
#
# We consider a rectangular block with a given width (**W**), height (**T**), and density ($\rho_b$), embedded in a viscous medium with viscosity ($\eta_m$) and density ($\rho_m$). The computational domain is also rectangular, with a length of $L = 500\ \textrm{km}$ and a height of $H = 500\ \textrm{km}$. We impose *free-slip* velocity boundary conditions along all boundaries.
#
# <img src="../Figures/Exercise09_1.png" alt="drawing" width="450"/> <br>
# **Fig. 1.** Model setup.
#
# A detailed description of the numerical grid, together with the discretization of the **momentum conservation** and **mass conservation** equations for *free-slip* and *no-slip* boundary conditions, is provided [here](https://geosci-ffm.github.io/GeoModBox.jl/dev/man/theory/MomentumMain/). Since these topics have already been introduced, we omit a detailed discussion in this exercise.
#
# Our goal is to incorporate as many of the available advection methods as possible into this problem. Consequently, in addition to extending the model to a time-dependent formulation, several further modifications to the numerical implementation are required.
#
# For additional background information, see the [previous exercise](./09_2D_Falling_Block.ipynb).
#
# ----------

# %% [markdown]
# Let us first load the modules required for visualizing the results, solving the linear system, defining the initial conditions, and solving the two-dimensional momentum conservation equation. Since this exercise also includes material advection and passive tracers, several additional modules are required.

# %%
using Plots
using ExtendableSparse
using GeoModBox.InitialCondition, GeoModBox.MomentumEquation.TwoD
using GeoModBox.AdvectionEquation.TwoD
using GeoModBox.Tracers.TwoD
using Base.Threads
using Printf
start=time()

# %% [markdown]
# We begin by using the tuple `FD` to specify the advection method.

# %%
# Define Numerical Scheme =========================================== #
# Advection ---
#   1) upwind, 2) slf, 3) semilag, 4) tracers
FD          =   (Method     = (Adv=:tracers,),)
# ------------------------------------------------------------------- #

# %% [markdown]
# The built-in function `IniPhase!()` is used to generate the initial material-phase distribution for the **block** problem. Depending on the selected problem setup, the function creates the corresponding initial distribution on the numerical grid. To use this function, we define the tuple `Ini`, which specifies the initial distribution of the material phase `p`.
#
# The phase distribution generated by `IniPhase!()` at the cell centers is then used to assign the corresponding density to each material phase. The resulting density field is subsequently used by the grid-based advection methods.

# %%
# Define Initial Condition ========================================== #
# Density --- 
#   1) block
Ini         =   (p=:block,) 
# ------------------------------------------------------------------- #
# Plot Settings ===================================================== #
Pl  =   (
    qinc    =   5,
    qsc     =   100*(60*60*24*365.25)*5e1
)
# ------------------------------------------------------------------- #

# %% [markdown]
# Next, we define the geometry of our model domain.

# %%
 # Geometry ========================================================== #
 M       =   (
    xmin    =   0.0,
    xmax    =   500.0e3,    # [ m ]
    ymin    =   -500.0e3,   # [ m ]
    ymax    =   0.0,
)
# ------------------------------------------------------------------- #

# %% [markdown]
# Now we define our grid resolution $\left(nc_x = nc_y = 50\right)$ and the numerical grid.
#
# We need to specify both the grid spacing $\Delta{x}$ and $\Delta{y}$, as well as the coordinates of the different grid points (*vertices* and *centroids*).
# To do this, we first define the respective 1-D coordinate vectors, from which the 2-D coordinate grids are then generated.

# %%
# Grid ============================================================== #
NC      =   (
    x   =   50, 
    y   =   50,
)
NV      =   (
    x   =   NC.x + 1,
    y   =   NC.y + 1,
)
Δ       =   (
    x   =   (M.xmax - M.xmin)/NC.x,
    y   =   (M.ymax - M.ymin)/NC.y,
)
x       =   (
    c   =   LinRange(M.xmin+Δ.x/2,M.xmax-Δ.x/2,NC.x),
    ce  =   LinRange(M.xmin - Δ.x/2.0, M.xmax + Δ.x/2.0, NC.x+2),
    v   =   LinRange(M.xmin,M.xmax,NV.x),
)
y       =   (
    c   =   LinRange(M.ymin+Δ.y/2,M.ymax-Δ.y/2,NC.y),
    ce  =   LinRange(M.ymin - Δ.y/2.0, M.ymax + Δ.y/2.0, NC.y+2),
    v   =   LinRange(M.ymin,M.ymax,NV.y),
)
x1      =   (
    c2d     =   x.c .+ 0*y.c',
    v2d     =   x.v .+ 0*y.v', 
    vx2d    =   x.v .+ 0*y.ce',
    vy2d    =   x.ce .+ 0*y.v',
)
x   =   merge(x,x1)
y1      =   (
    c2d     =   0*x.c .+ y.c',
    v2d     =   0*x.v .+ y.v',
    vx2d    =   0*x.v .+ y.ce',
    vy2d    =   0*x.ce .+ y.v',
)
y   =   merge(y,y1)
# ------------------------------------------------------------------- #

# %% [markdown]
# Next, we define the physical parameters of the model: the gravitational acceleration $g$, the viscosity $\eta_0$ ($10^{21}$ Pa·s), the background density $\rho_0$ (3200 kg/m³), and the density of the block $\rho_1$ (3300 kg/m³).
#
# The vector `phase` contains the phase identifiers that are used by the functions `IniPhase!()` and `IniTracer2D()` to assign the corresponding material phase. The vector `ρ` contains the density values associated with each material phase.

# %%
# Physics =========================================================== #
g       =   9.81

η₀      =   1.0e21

ρ₀      =   3200.0          #   Background density
ρ₁      =   3300.0          #   Block density

ρ       =   [ρ₀,ρ₁] 
phase   =   [0,1]
# ------------------------------------------------------------------- #

# %% [markdown]
# For our time-dependent problem, we again define only the location for saving the animation.

# %%
# Animationsettings ================================================= #
path        =   string("./Results/")
anim        =   Plots.Animation(path, String[] )
filename    =   string("10_Falling_",Ini.p,"_iso_td_",FD.Method.Adv)
save_fig    =   1
# ------------------------------------------------------------------- #

# %% [markdown]
# Now we define the sizes of the required fields. **In this case, we also introduce some new fields.**

# %%
# Allocation ======================================================== #
D   =   (
    vx      =   zeros(Float64,NV.x,NC.y+2),
    vy      =   zeros(Float64,NC.x+2,NV.y),
    Pt      =   zeros(Float64,NC...),
    p       =   zeros(Float64,NC...),
    p_ex    =   zeros(Float64,NC.x+2,NC.y+2),
    ρ       =   zeros(Float64,NC...),
    ρ_ex    =   zeros(Float64,NC.x+2,NC.y+2),
    ρ_exo   =   zeros(Float64,NC.x+2,NC.y+2),
    vxc     =   zeros(Float64,NC...),
    vyc     =   zeros(Float64,NC...),
    vxco    =   zeros(Float64,NC...),
    vyco    =   zeros(Float64,NC...),
    vc      =   zeros(Float64,NC...),
    wt      =   zeros(Float64,(NC.x,NC.y)),
    wte     =   zeros(Float64,(NC.x+2,NC.y+2)),
    wtv     =   zeros(Float64,(NV...)),
)
# ------------------------------------------------------------------- #

# %% [markdown]
# Next, we define the boundary and initial conditions.
#
# As in the previous exercises, we use the tuple `VBC` to specify the boundary conditions. It defines the boundary type (*free-slip* or *no-slip*) at each side of the domain (**E**, **W**, **S**, and **N**). The parameter `val` specifies the prescribed velocity at the corresponding boundary.

# %%
# Boundary Conditions =============================================== #
VBC     =   (
    type    =   (E=:freeslip,W=:freeslip,S=:freeslip,N=:freeslip),
    val     =   (E=zeros(NV.y),W=zeros(NV.y),S=zeros(NV.x),N=zeros(NV.x),
                vxE=zeros(NC.y),vxW=zeros(NC.y),vyS=zeros(NC.x),vyN=zeros(NC.x)),
)
# ------------------------------------------------------------------- #

# %% [markdown]
# Next, we need to define the parameters for time and the time step length.

# %%
# Time ============================================================== #
T   =   ( 
    tmax    =   [0.0],  
    Δfac    =   1.0,    # Courant time factor, i.e. dtfac*dt_courant
    Δ       =   [0.0],
    Time    =   [0.0,0.0],
)
T.tmax[1]   =   9.886 * 1e6 * (60*60*24*365.25)   # [ s ]
nt          =   9999
# ------------------------------------------------------------------- #

# %% [markdown]
# For tracer-based advection, the passive tracers must first be initialized. The function `IniTracer2D()` initializes the tracer distribution within the model domain and, if specified beforehand in the tuple `Ini`, assigns the corresponding material phase to each tracer.
#
# During the time loop, the tracers are advected by the flow and transport the material phase. The phase information stored on the tracers is then used by the function `Markers2Cells()` to interpolate the corresponding material property—in this case the density `ρ`—onto the numerical grid.
#
# If a grid-based advection method is selected instead, the density field is initialized directly on the grid. Note that the advection routines require the density field to be defined on the extended grid. The function `IniPhase!()` first assigns the appropriate material phase to each cell center, after which the corresponding density value is assigned to each phase. For the Staggered Leapfrog method, the density field from the previous timestep is additionally stored in `D.ρ_exo`.

# %%
# Tracer Advection ================================================== #
if FD.Method.Adv==:tracers 
    # Tracer Initialization ---
    nmx,nmy     =   5,5
    noise       =   0
    nmark       =   nmx*nmy*NC.x*NC.y
    Aparam      =   :phase
    MPC         =   (
            c       =   zeros(Float64,(NC.x,NC.y)),
            v       =   zeros(Float64,(NV.x,NV.y)),
            th      =   zeros(Float64,(nthreads(),NC.x,NC.y)),
            thv     =   zeros(Float64,(nthreads(),NV.x,NV.y)),
    )
    MAVG        = (
            PC_th   =   [similar(D.wte) for _ = 1:nthreads()],  # per thread
            PV_th   =   [similar(D.wtv) for _ = 1:nthreads()],   # per thread
            wte_th  =   [similar(D.wte) for _ = 1:nthreads()],  # per thread
            wtv_th  =   [similar(D.wtv) for _ = 1:nthreads()],  # per thread
    )
    Ma      =   IniTracer2D(Aparam,nmx,nmy,Δ,M,NC,noise,Ini.p,phase)
    # RK4 weights ---
    rkw     =   1.0/6.0*[1.0 2.0 2.0 1.0]   # for averaging
    rkv     =   1.0/2.0*[1.0 1.0 2.0 2.0]   # for time stepping
    # Count marker per cell ---
    CountMPC(Ma,nmark,MPC,M,x,y,Δ,NC,NV)
    # Interpolate from markers to cell ---
    Markers2Cells(Ma,nmark,MAVG.PC_th,D.ρ_ex,MAVG.wte_th,D.wte,x,y,Δ,Aparam,ρ)
    D.ρ     .=  D.ρ_ex[2:end-1,2:end-1]  
else
    # --------------------------------------------------------------- #
    # Initial Condition ============================================= #
    # Phase ---
    # If tracers are used, phases need to be defined on the tracers 
    # directly and are not suppose to be interpolated from the centroids! 
    IniPhase!(Ini.p,D,M,x,y,NC;phase)
    for i in eachindex(phase)
        D.ρ[D.p.==phase[i]] .= ρ[i]
    end
    D.ρ_ex[2:end-1,2:end-1]     .=  D.ρ
    D.ρ_ex[1,:]     .=   D.ρ_ex[2,:]
    D.ρ_ex[end,:]   .=   D.ρ_ex[end-1,:]
    D.ρ_ex[:,1]     .=   D.ρ_ex[:,2]
    D.ρ_ex[:,end]   .=   D.ρ_ex[:,end-1]
    D.ρ_exo         .=   D.ρ_ex
end
# ------------------------------------------------------------------- #

# %% [markdown]
# Next, we define the parameters required to set up the linear system of equations.
#
# The numbering of the equations for the *x-component* and *y-component* of the momentum conservation equation, as well as the *mass conservation* equation, together with the finite-difference discretization of the governing equations, is described in detail [here](https://geosci-ffm.github.io/GeoModBox.jl/dev/man/theory/MomentumMain/).
#
# We now construct the global numbering of the unknowns corresponding to the two velocity components and the pressure. This numbering determines the position of each grid variable within the global solution vector.

# %%
# System of Equations =============================================== #
# Numbering, without ghost nodes! ---
off    = [  NV.x*NC.y,                          # vx
            NV.x*NC.y + NC.x*NV.y,              # vy
            NV.x*NC.y + NC.x*NV.y + NC.x*NC.y]  # Pt

Num    =    (
    Vx  =   reshape(1:NV.x*NC.y, NV.x, NC.y), 
    Vy  =   reshape(off[1]+1:off[1]+NC.x*NV.y, NC.x, NV.y), 
    Pt  =   reshape(off[2]+1:off[2]+NC.x*NC.y,NC...),
)
# ------------------------------------------------------------------- #

# %% [markdown]
# The function `Assemblyc()` assembles the coefficient matrix $\mathbf{K}$ of the discretized Stokes system by assigning the appropriate coefficients to each equation. Since we consider an isoviscous problem, the coefficient matrix remains constant throughout the simulation. It therefore only needs to be assembled once before entering the time loop.

# %%
# Assemble Coefficients ============================================= #
K       =   Assemblyc(NC, NV, Δ, η₀, VBC, Num)
# ------------------------------------------------------------------- #

# %% [markdown]
# During each timestep,
#
# - the right-hand-side vector is updated to account for the current density distribution,
# - the linear system of equations is solved,
# - the density, velocity, and pressure fields are visualized,
# - the timestep size is determined, and
# - the density field or, alternatively, the material phase is advected.
#
# The timestep size is determined from a Courant-based stability criterion. This criterion limits the distance traveled during a single timestep relative to the grid spacing.

# %%
# Time Loop ========================================================= #
for it = 1:nt
    # Update Time ---
    T.Time[1]   =   T.Time[2] 
    @printf("Time step: #%04d, Time [Myr]: %04e\n ",it,
                T.Time[1]/(60*60*24*365.25)/1.0e6)
    # Momentum Equation ===
    # Update RHS ---
    rhs     =   updaterhsc( NC, NV, Δ, η₀, D.ρ, g, VBC, Num )
    # Solve System of Equations ---
    χ       =   K \ rhs
    # Update Unknown Variables ---
    D.vx[:,2:end-1]     .=  χ[Num.Vx]
    D.vy[2:end-1,:]     .=  χ[Num.Vy]
    D.Pt                .=  χ[Num.Pt]
    # ===
    # Get the velocity on the centroids ---
    for i = 1:NC.x
        for j = 1:NC.y
            D.vxc[i,j]  = (D.vx[i,j+1] + D.vx[i+1,j+1])/2
            D.vyc[i,j]  = (D.vy[i+1,j] + D.vy[i+1,j+1])/2
        end
    end
    @. D.vc        = sqrt(D.vxc^2 + D.vyc^2)
    # ---
    final_step = T.Time[2] >= T.tmax[1]
    # ---
    if mod(it,2) == 0 || final_step || it == 1
        p = heatmap(x.c./1e3,y.c./1e3,D.ρ',color=:inferno,
                xlabel="x[km]",ylabel="y[km]",colorbar=false,
                title="Density",
                aspect_ratio=:equal,xlims=(M.xmin/1e3, M.xmax/1e3), 
                ylims=(M.ymin/1e3, M.ymax/1e3),
                layout=(2,2),subplot=1)
        quiver!(p,x.c2d[1:Pl.qinc:end,1:Pl.qinc:end]./1e3,
                y.c2d[1:Pl.qinc:end,1:Pl.qinc:end]./1e3,
                quiver=(D.vxc[1:Pl.qinc:end,1:Pl.qinc:end].*Pl.qsc,
                        D.vyc[1:Pl.qinc:end,1:Pl.qinc:end].*Pl.qsc), 
                la=0.5,
                color="white",layout=(2,2),subplot=1)
        heatmap!(p,x.c./1e3,y.c./1e3,D.vxc',
                xlabel="x[km]",ylabel="y[km]",colorbar=false,
                title="V_x",color=cgrad(:batlow),
                aspect_ratio=:equal,xlims=(M.xmin/1e3, M.xmax/1e3),
                ylims=(M.ymin/1e3, M.ymax/1e3),
                layout=(2,2),subplot=3)
        heatmap!(p,x.c./1e3,y.c./1e3,D.vyc',
                xlabel="x[km]",ylabel="y[km]",colorbar=false,
                title="V_y",color=cgrad(:batlow),
                aspect_ratio=:equal,xlims=(M.xmin/1e3, M.xmax/1e3),
                ylims=(M.ymin/1e3, M.ymax/1e3),
                layout=(2,2),subplot=4)
        heatmap!(p,x.c./1e3,y.c./1e3,D.Pt',
                xlabel="x[km]",ylabel="y[km]",colorbar=false,
                title="P_t",color=cgrad(:lipari),
                aspect_ratio=:equal,xlims=(M.xmin/1e3, M.xmax/1e3),
                ylims=(M.ymin/1e3, M.ymax/1e3),
                layout=(2,2),subplot=2)
        if save_fig == 1
            Plots.frame(anim)
        elseif save_fig == 0
            display(p)
        end
    end
    if final_step
        break
    end
     # Calculate Time Stepping ---
    T.Δ[1]      =   T.Δfac * minimum((Δ.x,Δ.y)) / 
                        (sqrt(maximum(abs.(D.vx))^2 + maximum(abs.(D.vy))^2))
    @printf("\n")
    # Calculate Time ---
    T.Time[2]   =   T.Time[1] + T.Δ[1]
    if T.Time[2] > T.tmax[1] 
        T.Δ[1]      =   T.tmax[1] - T.Time[1]
        T.Time[2]   =   T.Time[1] + T.Δ[1]
    end
    # Advection ===
    if FD.Method.Adv==:upwind
        upwindc2D!(D.ρ,D.ρ_ex,D.vxc,D.vyc,NC,T.Δ[1],Δ.x,Δ.y)
    elseif FD.Method.Adv==:slf
        slfc2D!(D.ρ,D.ρ_ex,D.ρ_exo,D.vxc,D.vyc,NC,T.Δ[1],Δ.x,Δ.y)
    elseif FD.Method.Adv==:semilag
        if it == 1
            @. D.vxco   =   D.vxc
            @. D.vyco   =   D.vyc
        end
        semilagc2D!(D.ρ,D.ρ_ex,D.vxc,D.vyc,D.vxco,D.vyco,x,y,T.Δ[1])
        @. D.vxco   =   D.vxc
        @. D.vyco   =   D.vyc
    elseif FD.Method.Adv==:tracers
        # Advect tracers ---
        @printf("Running on %d thread(s)\n", nthreads())  
        AdvectTracer2D(Ma,nmark,D,x,y,T.Δ[1],Δ,NC,rkw,rkv)
        CountMPC(Ma,nmark,MPC,M,x,y,Δ,NC,NV)
        # Interpolate phase from tracers to grid ---
        Markers2Cells(Ma,nmark,MAVG.PC_th,D.ρ_ex,MAVG.wte_th,D.wte,x,y,Δ,Aparam,ρ)
        D.ρ     .=   D.ρ_ex[2:end-1,2:end-1]  
    end
end # End Time Loop

# %% [markdown]
# Finally, we save the animation to file for later inspection and analysis.

# %%
# Save Animation ==================================================== #
if save_fig == 1
    # Write the frames to a GIF file
    Plots.gif(anim, string( path, filename, ".gif" ), fps = 15)
    foreach(rm, filter(startswith(string(path,"00")), readdir(path,join=true)))
end
